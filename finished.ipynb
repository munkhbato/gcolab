# %% [markdown]
# <a href="https://colab.research.google.com/github/munkhbato/gcolab/blob/master/finished.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !scrapy crawl spidey
# Out:
# 2020-08-12 00:44:05 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: email_collecter)
# 2020-08-12 00:44:05 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.9 (default, Jul 17 2020, 12:50:27) - [GCC 8.4.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 3.0, Platform Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic
# 2020-08-12 00:44:05 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'email_collecter',
#  'CONCURRENT_REQUESTS': 64,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 4,
#  'COOKIES_ENABLED': False,
#  'LOG_LEVEL': 'INFO',
#  'NEWSPIDER_MODULE': 'email_collecter.spiders',
#  'RETRY_ENABLED': False,
#  'SPIDER_MODULES': ['email_collecter.spiders'],
#  'USER_AGENT': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, '
#                'like Gecko) Chrome/80.0.3987.132 Safari/537.36'}
# ...
