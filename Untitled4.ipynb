# %% [markdown]
# <a href="https://colab.research.google.com/github/munkhbato/gcolab/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !scrapy crawl spidey
# Out:
# /usr/local/lib/python3.6/dist-packages/scrapy/extensions/feedexport.py:239: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
# 2020-08-11 14:41:14 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET http://www.edusearchindia.org/> (failed 3 times): DNS lookup failed: no results for hostname lookup: www.edusearchindia.org.
# 2020-08-11 14:41:15 [scrapy.core.scraper] ERROR: Error downloading <GET http://www.edusearchindia.org/>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
#   File "/usr/local/lib/python3.6/dist-packages/twisted/python/failure.py", line 512, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
# ...
