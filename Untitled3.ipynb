# %% [markdown]
# <a href="https://colab.research.google.com/github/munkhbato/gcolab/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !scrapy crawl spidey
# Out:
# Streaming output truncated to the last 5000 lines.
# Unique links : 3
#
#  http://www.nobleinstitution.org/
# ['08026650404', '26640404']
# ['https://www.facebook.com/noblegrpofinstitutions/?eid=ARBT9IgNSUzFsHkaOWJvdUcky1eUcQjzYcwx2IGNxEo5jvQJiTamGfn90Z35f-nOQ2aZmpEQoTH-R4nJ', 'https://twitter.com/NInstitutions', 'http://linkdin.com/noblegroupofinstitutions', 'http://instagram.com/noble_groupofinstitutions', 'https://www.youtube.com/channel/UCbDyhBSEEPxaEyaAfBpCFYg?view_as=subscriber']
# All links    : 3
# Unique links : 2
#
#  https://www.bitm.edu.in/
# ['8392237150']
# []
# All links    : 6
# Unique links : 6
# []
# All links    : 3
# Unique links : 3
# 2020-08-11 11:47:17 [scrapy.core.scraper] ERROR: Error downloading <GET http://ibmtedu.org/>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
# ...
